# %%
import pandas as pd

# %%
data=pd.read_csv("WeatherData.csv")
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9         86                4
# 1     01-01-2012 01:00    -1.8              -3.7         87                4
# 2     01-01-2012 02:00    -1.8              -3.4         89                7
# 3     01-01-2012 03:00    -1.5              -3.2         88                6
# 4     01-01-2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape  # total no of rows and columns shown
# Out:
# (8784, 8)

# %%
data.index                #shows +1 stop value
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns      # names of columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Weather'].unique     #shows unique values in weather column, can be applied on single column only
# Out:
# <bound method Series.unique of 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object>

# %%
data.nunique()   #shows total no of unique values in each column.can be applied on single column as well as whole dataframe
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.count() #shows total no of non null values in each column
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
for col in data.columns:
    print(col)
# Out:
# Date/Time
# Temp_C
# Dew Point Temp_C
# Rel Hum_%
# Wind Speed_km/h
# Visibility_km
# Press_kPa
# Weather

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# ***Q) Find all unique wind speed and Visibility values ans total number***

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
data['Visibility_km'].unique()
# Out:
# array([ 8. ,  4. ,  4.8,  6.4,  1.2, 12.9, 16.1, 25. , 19.3, 24.1,  9.7,
#        11.3, 48.3,  3.2,  2.8,  2.4,  2. ,  0.8,  0.6,  1. ,  1.6,  3.6,
#         0.2,  0.4])

# %%
data['Visibility_km'].nunique()
# Out:
# 24

# %% [markdown]
# ***Find number of times when weather was exactly clear and how many times it snowed?***

# %%
data.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24   Clear
# 1            8.0     101.24   Clear

# %%
data.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#data.Weather=='Clear' this will give boolean values so use down syntax
data[data.Weather=='Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8         50               24
# 114   01-05-2012 18:00    -7.1             -14.4         56               11
# 115   01-05-2012 19:00    -9.2             -15.4         61                7
# 116   01-05-2012 20:00    -9.8             -15.7         62                9
# 117   01-05-2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data.groupby('Weather').get_group('Clear')    #get_group picks particular value from column
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8         50               24
# 114   01-05-2012 18:00    -7.1             -14.4         56               11
# 115   01-05-2012 19:00    -9.2             -15.4         61                7
# 116   01-05-2012 20:00    -9.8             -15.7         62                9
# 117   01-05-2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data[data.Weather=='Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55    01-03-2012 07:00   -14.0             -19.5         63               19
# 84    01-04-2012 12:00   -13.7             -21.7         51               11
# 86    01-04-2012 14:00   -11.3             -19.0         53                7
# 87    01-04-2012 15:00   -10.2             -16.3         61               11
# 88    01-04-2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data.groupby('Weather').get_group('Snow')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55    01-03-2012 07:00   -14.0             -19.5         63               19
# 84    01-04-2012 12:00   -13.7             -21.7         51               11
# 86    01-04-2012 14:00   -11.3             -19.0         53                7
# 87    01-04-2012 15:00   -10.2             -16.3         61               11
# 88    01-04-2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# ***No. of times when humidity was exactly 70%***

# %%
data[data['Rel Hum_%']== 70]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 29    01-02-2012 05:00     2.6              -2.3         70               32
# 30    01-02-2012 06:00     2.3              -2.6         70               26
# 31    01-02-2012 07:00     2.0              -2.9         70               33
# 107   01-05-2012 11:00    -5.6             -10.2         70               22
# 173   01-08-2012 05:00    -5.9             -10.5         70               13
# ...                ...     ...               ...        ...              ...
# 8405   12/16/2012 5:00   -10.0             -14.4         70               22
# 8566  12/22/2012 22:00    -7.4             -11.9         70               35
# 8634  12/25/2012 18:00    -8.9             -13.4         70               13
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
#
# ...

# %% [markdown]
# ***To find null values in dataset***

# %%
#data.isnull()   gives boolean result so use sum
data.isnull().sum()
#data.notnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       1
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# ***Renaming column Visibility_km to Visibility(km)***

# %%
data.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.rename(columns={'Visibility_km':'Visibility(km)'})        #to change permanently : inplace=True
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9         86                4
# 1     01-01-2012 01:00    -1.8              -3.7         87                4
# 2     01-01-2012 02:00    -1.8              -3.4         89                7
# 3     01-01-2012 03:00    -1.5              -3.2         88                6
# 4     01-01-2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ***Mean of temp, dewpoint, humidity, wind_speed, pressure***

# %%
mean_temp=data.Temp_C.mean()
print(f"Mean temp is:{mean_temp}")
# Out:
# Mean temp is:8.798144353369764

# %%
mean_windspd=data.Wind Speed_km/h.mean()        
print(f"Mean dew_point is:{mean_windspd}")
# Out:
#   File "<ipython-input-83-43c7e5e28a88>", line 1
#     mean_windspd=data.Wind Speed_km/h.mean()
#                            ^
# SyntaxError: invalid syntax

# %%
data.rename(columns={'Wind Speed_km/h':'WindSpeed'},inplace=True)

# %%
data.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  WindSpeed  \
# 0  01-01-2012 00:00    -1.8              -3.9         86          4
# 1  01-01-2012 01:00    -1.8              -3.7         87          4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
mean_windspd=data.WindSpeed.mean()                  # like this we can find mean of columns
print(f"Mean wind speed is:{mean_windspd}")
# Out:
# Mean wind speed is:14.94546903460838

# %% [markdown]
# ***Std deviation of wind speed***

# %%
std_dev_wind=data.WindSpeed.std()
print(f"Std. deviation of wind_speed is:{std_dev_wind}")
# Out:
# Std. deviation of wind_speed is:8.688696079468851

# %% [markdown]
# ***Variance of wind***

# %%
var_wind=data.WindSpeed.var()
print(f"Variance of wind speed is:{var_wind}")
# Out:
# Variance of wind speed is:75.49343956137737

# %% [markdown]
# ***All instances when Cloudy Weather was recorded***

# %%
data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data[data['Weather']=='Cloudy']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  WindSpeed  \
# 17    01-01-2012 17:00     3.0               0.0         81         13
# 20    01-01-2012 20:00     3.2               1.3         87         19
# 21    01-01-2012 21:00     4.0               1.7         85         20
# 23    01-01-2012 23:00     5.3               2.0         79         30
# 25    01-02-2012 01:00     4.6               0.0         72         39
# ...                ...     ...               ...        ...        ...
# 8761   12/31/2012 1:00   -10.7             -14.0         77         15
# 8762   12/31/2012 2:00   -10.1             -13.4         77          9
# 8764   12/31/2012 4:00   -10.5             -12.8         83         11
# 8765   12/31/2012 5:00   -10.2             -12.4         84          6
# 8766   12/31/2012 6:00    -9.7             -11.7         85          4
#
#       Visibility_km  Press_kPa Weather
# 17             16.1      99.81  Cloudy
# ...

# %%
data[data['Weather'].str.contains('Cloudy')].head(10)            # cloudy and mostly cloudy
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  WindSpeed  \
# 16  01-01-2012 16:00     2.6              -0.2         82         13
# 17  01-01-2012 17:00     3.0               0.0         81         13
# 20  01-01-2012 20:00     3.2               1.3         87         19
# 21  01-01-2012 21:00     4.0               1.7         85         20
# 23  01-01-2012 23:00     5.3               2.0         79         30
# 25  01-02-2012 01:00     4.6               0.0         72         39
# 26  01-02-2012 02:00     3.9              -0.9         71         32
# 27  01-02-2012 03:00     3.7              -1.5         69         33
# 28  01-02-2012 04:00     2.9              -2.3         69         32
# 29  01-02-2012 05:00     2.6              -2.3         70         32
#
#     Visibility_km  Press_kPa        Weather
# 16           12.9      99.93  Mostly Cloudy
# 17           16.1      99.81         Cloudy
# 20           25.0      99.50         Cloudy
# ...

# %% [markdown]
# ***Instances where windspeed is greater than 13 and temperature is less than 5***

# %%
data[(data['WindSpeed']>13)&(data['Temp_C']<5)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  WindSpeed  \
# 9     01-01-2012 09:00    -1.3              -3.1         88         15
# 14    01-01-2012 14:00     0.8              -1.1         87         20
# 15    01-01-2012 15:00     1.8              -0.4         85         22
# 18    01-01-2012 18:00     3.8               1.0         82         15
# 19    01-01-2012 19:00     3.1               1.3         88         15
# ...                ...     ...               ...        ...        ...
# 8779  12/31/2012 19:00     0.1              -2.7         81         30
# 8780  12/31/2012 20:00     0.2              -2.4         83         24
# 8781  12/31/2012 21:00    -0.5              -1.5         93         28
# 8782  12/31/2012 22:00    -0.2              -1.8         89         28
# 8783  12/31/2012 23:00     0.0              -2.1         86         30
#
#       Visibility_km  Press_kPa Weather
# 9               4.0     101.20     Fog
# ...

# %% [markdown]
# ***Mean of each column against each weather condition***

# %%
data.groupby('Weather').mean().head(10)
# Out:
#                            Temp_C  Dew Point Temp_C  Rel Hum_%  WindSpeed  \
# Weather
# Clear                    6.825716          0.089367  64.497738  10.557315
# Cloudy                   7.970544          2.375810  69.592593  16.127315
# Drizzle                  7.353659          5.504878  88.243902  16.097561
# Drizzle,Fog              8.067500          7.033750  93.275000  11.862500
# Drizzle,Ice Pellets,Fog  0.400000         -0.700000  92.000000  20.000000
# Drizzle,Snow             1.050000          0.150000  93.500000  14.000000
# Drizzle,Snow,Fog         0.693333          0.120000  95.866667  15.533333
# Fog                      4.303333          3.159333  92.286667   7.946667
# Freezing Drizzle        -5.657143         -8.000000  83.571429  16.571429
# Freezing Drizzle,Fog    -2.533333         -4.183333  88.500000  17.000000
#
#                          Visibility_km   Press_kPa
# Weather
# Clear                        30.153243  101.587443
# ...

# %% [markdown]
# ***Minimum and Maximum value of each column against each weather condition***

# %%
data.groupby('Weather').min().head(5)
# Out:
#                                 Date/Time  Temp_C  Dew Point Temp_C  \
# Weather
# Clear                    01-03-2012 19:00   -23.3             -28.5
# Cloudy                   01-01-2012 17:00   -21.4             -26.8
# Drizzle                  05-01-2012 15:00     1.1              -0.2
# Drizzle,Fog              05-01-2012 16:00     0.0              -1.6
# Drizzle,Ice Pellets,Fog   12/17/2012 9:00     0.4              -0.7
#
#                          Rel Hum_%  WindSpeed  Visibility_km  Press_kPa
# Weather
# Clear                           20          0           11.3      99.52
# Cloudy                          18          0           11.3      98.39
# Drizzle                         74          0            6.4      97.84
# Drizzle,Fog                     85          0            1.0      98.65
# Drizzle,Ice Pellets,Fog         92         20            4.0     100.79

# %%
data.groupby('Weather').max().head(5)
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                     9/28/2012 4:00    32.8              20.4         99
# Cloudy                    9/30/2012 9:00    30.5              22.6         99
# Drizzle                   9/30/2012 3:00    18.8              17.7         96
# Drizzle,Fog               9/30/2012 2:00    19.9              19.1        100
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          WindSpeed  Visibility_km  Press_kPa
# Weather
# Clear                           33           48.3     103.63
# Cloudy                          54           48.3     103.65
# Drizzle                         30           25.0     101.56
# Drizzle,Fog                     28            9.7     102.07
# Drizzle,Ice Pellets,Fog         20            4.0     100.79
